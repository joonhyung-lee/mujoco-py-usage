# %% [markdown]
# # Rendering `UR5e` (glfw issue)

# %%
import mujoco_py
import numpy as np
import matplotlib.pyplot as plt
from mujoco_parser import MuJoCoParserClass
from util import rpy2r,pr2t,t2pr
np.set_printoptions(precision=2)
plt.rc('xtick',labelsize=6); plt.rc('ytick',labelsize=6)
# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline
print ("Ready.")
# Out:
# Ready.

# %% [markdown]
# ### Parse `UR5e`

# %%
env = MuJoCoParserClass(name='UR5e',xml_path='../asset/ur5e/ur5_rg2.xml')
print ("[%s] parsed."%(env.name))
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In [6], line 1
# ----> 1 env = MuJoCoParserClass(name='UR5e',xml_path='../asset/ur5e/ur5_rg2.xml')
#       2 print ("[%s] parsed."%(env.name))
#
# File ~/mujoco-usuage/code/mujoco_parser.py:26, in MuJoCoParserClass.__init__(self, name, xml_path)
#      24 self.VIEWER_EXIST = False
#      25 # Parse the xml file
# ---> 26 self._parse_xml()
#      27 # Reset
#      28 self.reset()
#
# File ~/mujoco-usuage/code/mujoco_parser.py:44, in MuJoCoParserClass._parse_xml(self)
#      42 # Basic MuJoCo model and sim
#      43 self.full_xml_path = os.path.abspath(os.path.join(self.cwd,self.xml_path))
# ---> 44 self.model         = mujoco_py.load_model_from_path(self.full_xml_path)
#      45 self.sim           = mujoco_py.MjSim(self.model)
#      46 # Parse model information
#
# File cymj.pyx:175, in mujoco_py.cymj.load_model_from_path()
#
# Exception: Failed to load XML file: /home/sangbeom/mujoco-usuage/asset/ur5e/ur5_rg2.xml. mj_loadXML error: b'XML parse error at line 267, column 5:\nError reading end tag.\n'

# %% [markdown]
# ### Get camera pose

# %%
env.init_viewer(window_width=0.5,window_height=0.5,
                cam_azimuth=100.0,cam_distance=3.0,
                cam_elevation=-22.0,cam_lookat=np.array([0.3,0.0,1.0]))

# Render
env.set_viewer(
    cam_azimuth   = 0,
    cam_distance  = 10,
    cam_elevation = -45, # -90~+90
    cam_lookat    = [0,0,0]
)

env.reset()
max_tick = 5000
while env.tick < max_tick:
    # Update
    env.step()
    
    # Get camera info
    if env.tick < 2000:
        vi = env.get_viewer_info()
        p_viewer = vi['cam_lookat']
        R_viewer = rpy2r(np.deg2rad([0,-vi['cam_elevation'],vi['cam_azimuth']]))
        T_viewer = pr2t(p_viewer,R_viewer)
        T_marker = T_viewer @ pr2t(np.array([-2,0,0]),np.eye(3)) # minus translate w.r.t. x
        p_marker,R_marker = t2pr(T_marker)
    
    # Plot coordinate
    env.add_marker_coordinate(
        p=[0,0,0],R=np.eye(3),axis_len=1.0,axis_width=0.01,label='World')
    env.add_marker_coordinate(
        p=p_viewer,R=R_viewer,axis_len=2,axis_width=0.05,label='')
    env.add_marker_sphere(
        p=p_marker,radius=0.1,rgba=[1,0,0,1])
    
    # Render
    tick_rate = env.tick / max_tick
    MOVE_CAMERA = False
    if MOVE_CAMERA:
        env.set_viewer(
            cam_azimuth   = 360.0*tick_rate,
            cam_elevation = 0.0*tick_rate - 45
        )
    
    env.render() 
print ("Done.")
# Out:
# GLFW error (code %d): %s 65544 b'X11: The DISPLAY environment variable is missing'
# GLFW error (code %d): %s 65544 b'X11: The DISPLAY environment variable is missing'
# ---------------------------------------------------------------------------
# GlfwError                                 Traceback (most recent call last)
# Cell In [4], line 1
# ----> 1 env.init_viewer(window_width=0.5,window_height=0.5,
#       2                 cam_azimuth=100.0,cam_distance=3.0,
#       3                 cam_elevation=-22.0,cam_lookat=np.array([0.3,0.0,1.0]))
#       5 # Render
#       6 env.set_viewer(
#       7     cam_azimuth   = 0,
#       8     cam_distance  = 10,
#       9     cam_elevation = -45, # -90~+90
#      10     cam_lookat    = [0,0,0]
#      11 )
#
# File ~/mujoco-usuage/code/mujoco_parser.py:293, in MuJoCoParserClass.init_viewer(self, window_width, window_height, cam_azimuth, cam_distance, cam_elevation, cam_lookat)
#     291 if not self.VIEWER_EXIST:
#     292     self.VIEWER_EXIST = True
# --> 293     self.viewer = mujoco_py.MjViewer(self.sim) # this will make a new window
#     294 # Set viewer
#     295 if (window_width is not None) and (window_height is not None):
#
# File ~/mujoco-py/mujoco_py/mjviewer.py:137, in MjViewer.__init__(self, sim)
#     136 def __init__(self, sim):
# --> 137     super().__init__(sim)
#     139     self._ncam = sim.model.ncam
#     140     self._paused = False  # is viewer paused.
#
# File ~/mujoco-py/mujoco_py/mjviewer.py:28, in MjViewerBasic.__init__(self, sim)
#      27 def __init__(self, sim):
# ---> 28     super().__init__(sim)
#      30     self._gui_lock = Lock()
#      31     self._button_left_pressed = False
#
# File mjrendercontext.pyx:311, in mujoco_py.cymj.MjRenderContextWindow.__init__()
#
# File mjrendercontext.pyx:46, in mujoco_py.cymj.MjRenderContext.__init__()
#
# File mjrendercontext.pyx:102, in mujoco_py.cymj.MjRenderContext._setup_opengl_context()
#
# File opengl_context.pyx:44, in mujoco_py.cymj.GlfwContext.__init__()
#
# File opengl_context.pyx:64, in mujoco_py.cymj.GlfwContext._init_glfw()
#
# GlfwError: Failed to initialize GLFW

# %%
env.plot_scene(figsize=(8,5),render_expand=2.0,title_str='UR5e (tick:%d)'%(env.tick),title_fs=11)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [5], line 1
# ----> 1 env.plot_scene(figsize=(8,5),render_expand=2.0,title_str='UR5e (tick:%d)'%(env.tick),title_fs=11)
#
# File ~/mujoco-usuage/code/mujoco_parser.py:124, in MuJoCoParserClass.plot_scene(self, figsize, render_w, render_h, render_expand, title_str, title_fs, RETURN_IMG)
#     119 """
#     120     Plot scene
#     121 """
#     122 if (render_w is None) and (render_h is None):
#     123     # default render size matches with actual window
# --> 124     render_w = self.viwer_width*render_expand
#     125     render_h = self.viwer_height*render_expand
#     126 for _ in range(10):
#
# AttributeError: 'MuJoCoParserClass' object has no attribute 'viwer_width'

# %% [markdown]
# ### Render with markers

# %%
env.init_viewer(window_width=0.5,window_height=0.5,
                cam_azimuth=100.0,cam_distance=3.0,
                cam_elevation=-22.0,cam_lookat=np.array([0.3,0.0,1.0]))
env.reset()
max_tick = 5000
while env.tick < max_tick:
    # Update
    env.step()
    
    # Get p and R of an end-effector
    p_eef = env.get_p_body(body_name='ee_link')
    R_eef = env.get_R_body(body_name='ee_link')
    
    # Plot plane
    p_plane = [1.0,0.0,0.1]
    R_plane = np.eye(3)
    env.add_marker_plane(
        p=p_plane,R=R_plane,xy_widths=[0.5,0.5],rgba=[0.0,1.0,1.0,0.9],label='Plane')
    
    # Plot sphere
    p_sphere = [1.0,0.0,0.25]
    env.add_marker_sphere(
        p=p_sphere,radius=0.05,rgba=[1.0,0.0,0.0,0.9],label='Sphere')
    
    # Plot box
    p_box = [1.0,0.0,0.5]
    R_box = R_eef # np.eye(3)
    env.add_marker_box(
        p=p_box,R=R_box,size=[0.025,0.025,0.1],rgba=[0.0,1.0,0.0,0.9],label='Box')
    
    # Plot capsule
    p_capsule = [1.0,0.0,0.75]
    R_capsule = R_eef # np.eye(3)
    env.add_marker_capsule(
        p=p_capsule,R=R_capsule,size=[0.025,0.025,0.1],rgba=[0.0,0.0,1.0,0.9],label='Capsule')
        
    # Plot cylinder
    p_cylinder = [1.0,0.0,1.0]
    R_cylinder = R_eef # np.eye(3)
    env.add_marker_cylinder(
        p=p_cylinder,R=R_cylinder,size=[0.025,0.025,0.1],rgba=[1.0,1.0,0.0,0.9],label='Cylinder')
    
    # Plot arrow
    p_arrow = [1.0,0.0,1.25]
    R_arrow = R_eef # np.eye(3)
    env.add_marker_arrow(
        p=p_arrow,R=R_arrow,size=[0.025,0.025,0.25],rgba=[1.0,0.0,1.0,0.9],label='Arrow')
    
    # Plot coordinate
    p_coord    = [1.0,0.0,1.5]
    R_coord    = R_eef # rpy2r(np.deg2rad([0,0,0]))
    env.add_marker_coordinate(
        p=p_coord,R=R_coord,axis_len=0.5,axis_width=0.01,label='Coordinate')
    env.add_marker_coordinate(
        p=[0,0,0],R=np.eye(3),axis_len=1.0,axis_width=0.01,label='World')
    
    env.render()
print ("Done.")
# Out:
# Done.

# %%
env.plot_scene(figsize=(8,5),render_expand=2.0,title_str='UR5e (tick:%d)'%(env.tick),title_fs=11)

# %% [markdown]
# ### Render

# %%
env.init_viewer(window_width=0.5,window_height=0.5,
                cam_azimuth=80.0,cam_distance=3.0,
                cam_elevation=-30.0,cam_lookat=np.array([0,0,1.5]))
env.reset()
max_tick = 2000
while env.tick < max_tick:
    env.step()
    env.render()
print ("Done.")
# Out:
# Done.

# %%
env.forward_renders()
env.plot_scene(figsize=(8,5),render_expand=2.0,title_str='UR5e (tick:%d)'%(env.tick),title_fs=11)

# %% [markdown]
# ### Get viewer information

# %%
viewer_info = env.get_viewer_info()
print (viewer_info)
# Out:
# {'cam_azimuth': 53.53873239436619, 'cam_distance': 3.0, 'cam_elevation': -55.8274647887324, 'cam_lookat': array([0. , 0. , 1.5])}

# %% [markdown]
# ### Render again with restoring previous viewer information

# %%
env.init_viewer(window_width=0.5,window_height=0.5,
                cam_azimuth=viewer_info['cam_azimuth'],cam_distance=viewer_info['cam_distance'],
                cam_elevation=viewer_info['cam_elevation'],cam_lookat=viewer_info['cam_lookat']
               )
env.reset()
max_tick = 2000
while env.tick < max_tick:
    env.step()
    env.render()
print ("Done.")
# Out:
# Done.

# %%
env.forward_renders()
env.plot_scene(figsize=(8,5),render_expand=2.0,title_str='UR5e (tick:%d)'%(env.tick),title_fs=11)

# %%
env.terminate_viewer()
