# %% [markdown]
# ### Parse `UR5e` in MuJoCo

# %%
import os
import time
import cv2  # image plot
import glfw # opengl
import numpy as np
import mujoco_py
import matplotlib.pyplot as plt
from screeninfo import get_monitors # get monitor size
np.set_printoptions(precision=2)
# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline
print ("Ready.")
# Out:
# Ready.

# %% [markdown]
# ### MuJoCo parser class

# %%
class MuJoCoParserClass(object):
    def __init__(self,
                 name     = 'Robot',
                 xml_path = ''
                ):
        """
            Initialize MuJoCo parser
        """
        self.name        = name
        self.xml_path    = xml_path
        self.cwd         = os.getcwd()
        # Simulation
        self.tick         = 0
        self.VIEWER_EXIST = False
        # Parse the xml file
        self._parse_xml()
        # Reset
        self.reset()
        
    def _parse_xml(self):
        """
            Parse an xml file
        """
        # Basic MuJoCo model and sim
        self.full_xml_path = os.path.abspath(os.path.join(self.cwd,self.xml_path))
        self.model         = mujoco_py.load_model_from_path(self.full_xml_path)
        self.sim           = mujoco_py.MjSim(self.model)
        # Parse model information
        self.dt              = self.sim.model.opt.timestep 
        self.HZ              = int(1/self.dt)
        self.n_body          = self.model.nbody
        self.body_names      = list(self.sim.model.body_names)
        self.n_joint         = self.model.njnt
        self.joint_idxs      = np.arange(0,self.n_joint,1)
        self.joint_names     = [self.sim.model.joint_id2name(x) for x in range(self.n_joint)]
        self.joint_types     = self.sim.model.jnt_type # 0:free, 1:ball, 2:slide, 3:hinge
        self.joint_range     = self.sim.model.jnt_range
        self.actuator_names  = list(self.sim.model.actuator_names)
        self.n_actuator      = len(self.actuator_names)
        self.torque_range    = self.sim.model.actuator_ctrlrange
        self.rev_joint_idxs  = np.where(self.joint_types==3)[0].astype(np.int32) # revolute joint indices
        self.rev_joint_names = [self.joint_names[x] for x in self.rev_joint_idxs]
        self.n_rev_joint     = len(self.rev_joint_idxs)
        self.rev_qvel_idxs   = [self.sim.model.get_joint_qvel_addr(x) for x in self.rev_joint_names]
        self.geom_names      = list(self.sim.model.geom_names)
        self.n_geom          = len(self.geom_names)
        
    def print_env_info(self):
        """
            Print env info
        """
        print ("[%s] Instantiated from [%s]"%(self.name,self.full_xml_path))
        print ("- Simulation timestep is [%.4f]sec and frequency is [%d]HZ"%(self.dt,self.HZ))
        print ("- [%s] has [%d] bodies"%(self.name,self.n_body))
        for b_idx in range(self.n_body):
            body_name  = self.body_names[b_idx]
            print (" [%02d] body name:[%s]"%(b_idx,body_name))
        print ("- [%s] has [%d] joints"%(self.name,self.n_joint))
        for j_idx in range(self.n_joint):
            joint_name = self.joint_names[j_idx]
            joint_type = self.joint_types[j_idx]
            if joint_type == 0:
                joint_type_str = 'free'
            elif joint_type == 1:
                joint_type_str = 'ball'
            elif joint_type == 2:
                joint_type_str = 'prismatic'
            elif joint_type == 3:
                joint_type_str = 'revolute'
            else:
                joint_type_str = 'unknown'
            print (" [%02d] name:[%s] type:[%s] joint range:[%.2f to %.2f]"%
                (j_idx,joint_name,joint_type_str,self.joint_range[j_idx,0],self.joint_range[j_idx,1]))
        print ("- [%s] has [%d] revolute joints"%(self.name,self.n_rev_joint))
        for j_idx in range(self.n_rev_joint):
            rev_joint_idx  = self.rev_joint_idxs[j_idx]
            rev_joint_name = self.rev_joint_names[j_idx]
            print (" [%02d] joint index:[%d] and name:[%s]"%(j_idx,rev_joint_idx,rev_joint_name))
        print  ("- [%s] has [%d] actuators"%(self.name,self.n_actuator))
        for a_idx in range(self.n_actuator):
            actuator_name = self.actuator_names[a_idx]
            print (" [%02d] actuator name:[%s] torque range:[%.2f to %.2f]"%
            (a_idx,actuator_name,self.torque_range[a_idx,0],self.torque_range[a_idx,1]))
        print  ("- [%s] has [%d] geometries"%(self.name,self.n_geom))
        for g_idx in range(self.n_geom):
            geom_name = self.geom_names[g_idx]
            print (" [%02d] geometry name:[%s]"%(g_idx,geom_name))
            
    def plot_scene(self,
                   figsize       = (12,8),
                   render_w      = 1200,
                   render_h      = 800,
                   title_str     = None,
                   title_fs      = 10,
                   RETURN_IMG    = False):
        """
            Plot scene
        """
        self.init_viewer()
        img = self.viewer.read_pixels(width=render_w,height=render_h,depth=False)
        img = cv2.flip(cv2.rotate(img,cv2.ROTATE_180),1) # 0:up<->down, 1:left<->right
        if RETURN_IMG: # return RGB image
            return img
        else: # plot image
            plt.figure(figsize=figsize)
            plt.imshow(img)
            if title_str is not None:
                plt.title(title_str,fontsize=title_fs)
            plt.axis('off')
            plt.show()
            
    def reset(self,RESET_GLFW=False):
        """
             Reset simulation
        """
        self.tick = 0
        self.sim.reset()

    def init_viewer(self,
                    window_width  = None,
                    window_height = None):
        """
            Initialize viewer
        """
        if not self.VIEWER_EXIST:
            self.VIEWER_EXIST = True
            self.viewer = mujoco_py.MjViewer(self.sim) # this will make a new window
            self.viewer.cam.fixedcamid = 4
            self.viewer.cam.type = 0
        # Set viewer
        if (window_width is not None) and (window_height is not None):
            self.set_viewer(window_width=window_width,window_height=window_height)
            
    def set_viewer(self,
                   window_width    = 0.5,
                   window_height   = 0.5):
        """
            Set viewer
        """
        if self.VIEWER_EXIST:
            self.window = self.viewer.window
            self.viwer_width  = int(window_width*get_monitors()[0].width)
            self.viwer_height = int(window_height*get_monitors()[0].height)
            glfw.set_window_size(
                window = self.window,
                width  = self.viwer_width,
                height = self.viwer_height)
            
    def terminate_viewer(self):
        """
            Terminate viewer
        """
        if self.VIEWER_EXIST:
            self.VIEWER_EXIST = False 
            self.viewer.render() # render once before terminate
            time.sleep(1.0)
            glfw.terminate() # terminate
            time.sleep(1.0) 
            glfw.init() # initialize once

    def step(self):
        """
            Step simulation
        """
        self.tick = self.tick + 1
        # Forward dynamics
        self.sim.step()
        
    def forward(self,q_pos=None,q_pos_idxs=None):
        """
            Forward kinemaatics
        """
        self.tick = self.tick + 1
        if q_pos is not None:
            if q_pos_idxs is None:
                self.sim.data.qpos[:] = q_pos
            else:
                self.sim.data.qpos[q_pos_idxs] = q_pos
        self.sim.forward()

    def render(self):
        """
            Render simulation
        """
        self.viewer.render()

print ("Ready.")
# Out:
# Ready.

# %%
env = MuJoCoParserClass(name='UR5e',xml_path='../asset/ur5e/object_depth.xml')
env.init_viewer(window_width=1.0,window_height=1.0) # init viewer
env.print_env_info()
print ("Done.")
# Out:
# Creating window glfw
# [UR5e] Instantiated from [/home/rilab/mujoco-usuage/asset/ur5e/object_depth.xml]
# - Simulation timestep is [0.0020]sec and frequency is [500]HZ
# - [UR5e] has [22] bodies
#  [00] body name:[world]
#  [01] body name:[table]
#  [02] body name:[box_link]
#  [03] body name:[base_link]
#  [04] body name:[shoulder_link]
#  [05] body name:[upper_arm_link]
#  [06] body name:[forearm_link]
#  [07] body name:[wrist_1_link]
#  [08] body name:[wrist_2_link]
#  [09] body name:[wrist_3_link]
#  [10] body name:[ee_link]
#  [11] body name:[robotiq_85_base_link]
#  [12] body name:[left_inner_knuckle]
#  [13] body name:[left_inner_finger]
#  [14] body name:[right_inner_knuckle]
#  [15] body name:[right_inner_finger]
#  [16] body name:[base]
#  [17] body name:[box_1]
#  [18] body name:[box_2]
#  [19] body name:[box_3]
#  [20] body name:[cylinder_1]
#  [21] body name:[cylinder_2]
# - [UR5e] has [26] joints
#  [00] name:[shoulder_pan_joint] type:[revolute] joint range:[-3.14 to 3.14]
#  [01] name:[shoulder_lift_joint] type:[revolute] joint range:[-3.14 to 0.00]
#  [02] name:[elbow_joint] type:[revolute] joint range:[-3.14 to 3.14]
#  [03] name:[wrist_1_joint] type:[revolute] joint range:[-3.14 to 3.14]
#  [04] name:[wrist_2_joint] type:[revolute] joint range:[-3.14 to 3.14]
#  [05] name:[wrist_3_joint] type:[revolute] joint range:[-3.14 to 3.14]
#  [06] name:[base_to_lik] type:[revolute] joint range:[-1.00 to 1.00]
#  [07] name:[base_to_rik] type:[revolute] joint range:[-1.00 to 1.00]
#  [08] name:[box_1_x] type:[prismatic] joint range:[-5.00 to 5.00]
#  [09] name:[box_1_y] type:[prismatic] joint range:[-5.00 to 5.00]
#  [10] name:[box_1_z] type:[prismatic] joint range:[-2.00 to 2.00]
#  [11] name:[box_1_rot] type:[ball] joint range:[0.00 to 0.00]
#  [12] name:[box_2_x] type:[prismatic] joint range:[-5.00 to 5.00]
#  [13] name:[box_2_y] type:[prismatic] joint range:[-5.00 to 5.00]
#  [14] name:[box_2_z] type:[prismatic] joint range:[-2.00 to 2.00]
#  [15] name:[box_2_rot] type:[ball] joint range:[0.00 to 0.00]
#  [16] name:[box_3_x] type:[prismatic] joint range:[-5.00 to 5.00]
#  [17] name:[box_3_y] type:[prismatic] joint range:[-5.00 to 5.00]
#  [18] name:[box_3_z] type:[prismatic] joint range:[-2.00 to 2.00]
#  [19] name:[box_3_rot] type:[ball] joint range:[0.00 to 0.00]
#  [20] name:[cylinder_1_x] type:[prismatic] joint range:[-5.00 to 5.00]
#  [21] name:[cylinder_1_y] type:[prismatic] joint range:[-5.00 to 5.00]
#  [22] name:[cylinder_1_z] type:[prismatic] joint range:[-2.00 to 2.00]
#  [23] name:[cylinder_2_x] type:[prismatic] joint range:[-5.00 to 5.00]
#  [24] name:[cylinder_2_y] type:[prismatic] joint range:[-5.00 to 5.00]
#  [25] name:[cylinder_2_z] type:[prismatic] joint range:[-2.00 to 2.00]
# - [UR5e] has [8] revolute joints
#  [00] joint index:[0] and name:[shoulder_pan_joint]
#  [01] joint index:[1] and name:[shoulder_lift_joint]
#  [02] joint index:[2] and name:[elbow_joint]
#  [03] joint index:[3] and name:[wrist_1_joint]
#  [04] joint index:[4] and name:[wrist_2_joint]
#  [05] joint index:[5] and name:[wrist_3_joint]
#  [06] joint index:[6] and name:[base_to_lik]
#  [07] joint index:[7] and name:[base_to_rik]
# - [UR5e] has [7] actuators
#  [00] actuator name:[shoulder_pan_T] torque range:[-2.00 to 2.00]
#  [01] actuator name:[shoulder_lift_T] torque range:[-2.00 to 2.00]
#  [02] actuator name:[forearm_T] torque range:[-2.00 to 2.00]
#  [03] actuator name:[wrist_1_T] torque range:[-1.00 to 1.00]
#  [04] actuator name:[wrist_2_T] torque range:[-1.00 to 1.00]
#  [05] actuator name:[wrist_3_T] torque range:[-1.00 to 1.00]
#  [06] actuator name:[gripper_motor] torque range:[-1.00 to 1.00]
# - [UR5e] has [6] geometries
#  [00] geometry name:[floor]
#  [01] geometry name:[box_1]
#  [02] geometry name:[box_2]
#  [03] geometry name:[box_3]
#  [04] geometry name:[cylinder_1]
#  [05] geometry name:[cylinder_2]
# Done.

# %% [markdown]
# ### Plot

# %%
tick = 0
while tick < 50:
    tick = tick + 1
    env.forward()
    env.render()
env.plot_scene(figsize=(8,5),render_w=env.viwer_width,render_h=env.viwer_height,
               title_str='Panda (tick:%d)'%(env.tick),title_fs=13)

# %% [markdown]
# ### Animate

# %%
env.reset()
while env.tick <= 5000:
    env.step()
    env.render()
print ("Done.")
# Out:
# Done.

# %% [markdown]
# ### Plot again

# %%
env.plot_scene(figsize=(8,5),render_w=env.viwer_width,render_h=env.viwer_height,
               title_str='Panda (tick:%d)'%(env.tick),title_fs=13)

# %% [markdown]
# ### Terminate viewer

# %%
env.terminate_viewer()
print ("Viewer terminated.")
# Out:
# Viewer terminated.
